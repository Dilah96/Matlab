% %% [markdown]
% # x=5;

% %%
y=2
% Out:
% y =
%
%      2

% %% [markdown]
% Si può scrivere anche in latex $$x^2$$

% %%
%Puoi definire vettori e stampare i grafici
x=linspace(1,10,100);
z=x*2;
plot(x,z)
